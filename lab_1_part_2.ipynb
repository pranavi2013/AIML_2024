# %% [markdown]
# <a href="https://colab.research.google.com/github/pranavi2013/AIML_2024/blob/main/lab_1_part_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
people = ['kiran', 'arun', 'vijay', 'varun']
age = [25, 30, 35, 45]
height = [145, 151, 165, 173]
weight = [45, 55, 65, 75]
healthcare_data = {
    'Person': people,
    'Age': age,
    'Height': height,
    'Weight': weight
}
healthcare_df = pd.DataFrame(healthcare_data)
print(healthcare_df)
# Out:
#   Person  Age  Height  Weight
# 0  kiran   25     145      45
# 1   arun   30     151      55
# 2  vijay   35     165      65
# 3  varun   45     173      75

# %%
import matplotlib.pyplot as plt

plt.scatter(healthcare_df['Age'], healthcare_df['Height'])
plt.title('Scatter Plot: Age vs. Height')
plt.xlabel('Age')
plt.ylabel('Height')
plt.show()

# %%
plt.bar(healthcare_df['Person'], healthcare_df['Weight'])
plt.title('Bar Chart: Person vs. Weight')
plt.xlabel('Person')
plt.ylabel('Weight')
plt.show()

# %%
plt.hist(healthcare_df['Age'], bins=10, color='blue', edgecolor='black')
plt.title('Histogram: Age Distribution')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %%
import matplotlib.pyplot as plt

plt.scatter(healthcare_df['Age'], healthcare_df['Height'])
plt.title('Scatter Plot: Age vs. Height')
plt.xlabel('Age')
plt.ylabel('Height (in cm)')
plt.grid(True)
plt.show()

# %%
plt.bar(healthcare_df['Person'], healthcare_df['Weight'])
plt.title('Bar Chart: Person vs. Weight')
plt.xlabel('Person')
plt.ylabel('Weight (in kg)')
plt.grid(axis='y')
plt.show()

# %%
plt.hist(healthcare_df['Age'], bins=10, color='blue', edgecolor='black')
plt.title('Histogram: Age Distribution')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.grid(axis='y')
plt.show()
